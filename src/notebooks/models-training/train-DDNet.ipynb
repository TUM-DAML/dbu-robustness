# %%
import torch
from src.models.distribution_distillation_networks.run import run
# Out:
# /nfs/homedirs/charpent/dbu-robustness/src/notebooks/models-training

# %%
use_cuda=True
print("CUDA Available: ",torch.cuda.is_available())
device = torch.device("cuda" if (use_cuda and torch.cuda.is_available()) else "cpu")
# Out:
# CUDA Available:  True

# %% [markdown]
# # Standard Training

# %%
# Dataset parameters
seed_dataset=123
dataset_name='MNIST'
ood_dataset_names=['KMNIST', 'FMNIST']
split=[.8, .2]

# Architecture parameters
seed_model=123
directory_model='../saved-models'
architecture='conv'
input_dims=[28, 28, 1]
output_dim=10
hidden_dims=[64, 64, 64]
kernel_dim=5
k_lipschitz=None
n_networks=5

# Training parameters
directory_results='../saved-results'
max_epochs=10
patience=5
frequency=2
batch_size=64
lr=1e-4
loss='Dir-LL'
adversarial_training = None
rs_sigma = None

# %%
results = run(
        # Dataset parameters
        seed_dataset,  # Seed to shuffle dataset. int
        dataset_name,  # Dataset name. string
        ood_dataset_names,  # OOD dataset names.  list of strings
        split,  # Split for train/val/test sets. list of floats

        # Architecture parameters
        seed_model,  # Seed to init model. int
        directory_model,  # Path to save model. string
        architecture,  # Encoder architecture name. string
        input_dims,  # Input dimension. List of ints
        output_dim,  # Output dimension. int
        hidden_dims,  # Hidden dimensions. list of ints
        kernel_dim,  # Input dimension. int
        k_lipschitz,  # Lipschitz constant. float or None (if no lipschitz)
        n_networks,  # Number of networks in ensemble. int

        # Training parameters
        directory_results,  # Path to save resutls. string
        max_epochs,  # Maximum number of epochs for training
        patience,  # Patience for early stopping. int
        frequency,  # Frequency for early stopping test. int
        batch_size,  # Batch size. int
        lr,  # Learning rate. float
        loss,  # Loss name. string

        adversarial_training,  # adversarial training
        rs_sigma,  # rs training
)
# Out:
# 2021-06-08 16:38:58 (INFO): Received the following configuration:
# 2021-06-08 16:38:58 (INFO): DATASET | seed_dataset 123 - dataset_name MNIST - ood_dataset_names ['KMNIST', 'FMNIST'] - split [0.8, 0.2]
# 2021-06-08 16:38:58 (INFO): ARCHITECTURE |  seed_model 123 -  architecture conv -  input_dims [28, 28, 1] -  output_dim 10 -  hidden_dims [64, 64, 64] -  kernel_dim 5 -  k_lipschitz None -  n_networks 5
# 2021-06-08 16:38:58 (INFO): TRAINING |  max_epochs 10 -  patience 5 -  frequency 2 -  batch_size 64 -  lr 0.0001 -  loss Dir-LL
# Sub-model 0
# Epoch 0 -> Val loss 0.212 | Val Acc.: 0.938
# Model saved
# Epoch 2 -> Val loss 0.093 | Val Acc.: 0.971
# Model saved
# Epoch 4 -> Val loss 0.071 | Val Acc.: 0.978
# Model saved
# Epoch 6 -> Val loss 0.056 | Val Acc.: 0.982
# Model saved
# Epoch 8 -> Val loss 0.044 | Val Acc.: 0.986
# Model saved
#
# Sub-model 1
# Epoch 0 -> Val loss 0.235 | Val Acc.: 0.93
# Model saved
# Epoch 2 -> Val loss 0.114 | Val Acc.: 0.963
# Model saved
# Epoch 4 -> Val loss 0.078 | Val Acc.: 0.975
# Model saved
# Epoch 6 -> Val loss 0.069 | Val Acc.: 0.978
# Model saved
# Epoch 8 -> Val loss 0.061 | Val Acc.: 0.982
# Model saved
#
# Sub-model 2
# Epoch 0 -> Val loss 0.238 | Val Acc.: 0.93
# Model saved
# Epoch 2 -> Val loss 0.112 | Val Acc.: 0.966
# Model saved
# Epoch 4 -> Val loss 0.099 | Val Acc.: 0.971
# Model saved
# Epoch 6 -> Val loss 0.064 | Val Acc.: 0.98
# Model saved
# Epoch 8 -> Val loss 0.058 | Val Acc.: 0.982
# Model saved
#
# Sub-model 3
# Epoch 0 -> Val loss 0.251 | Val Acc.: 0.922
# Model saved
# Epoch 2 -> Val loss 0.113 | Val Acc.: 0.965
# Model saved
# Epoch 4 -> Val loss 0.088 | Val Acc.: 0.974
# Model saved
# Epoch 6 -> Val loss 0.063 | Val Acc.: 0.981
# Model saved
# Epoch 8 -> Val loss 0.062 | Val Acc.: 0.981
# Model saved
#
# Sub-model 4
# Epoch 0 -> Val loss 0.236 | Val Acc.: 0.929
# Model saved
# Epoch 2 -> Val loss 0.107 | Val Acc.: 0.965
# Model saved
# Epoch 4 -> Val loss 0.075 | Val Acc.: 0.976
# Model saved
# Epoch 6 -> Val loss 0.061 | Val Acc.: 0.98
# Model saved
# Epoch 8 -> Val loss 0.058 | Val Acc.: 0.981
# Model saved
# cuda
#
# Student Model
# /nfs/staff-hdd/charpent/anaconda3/envs/dbu-robustness/lib/python3.6/site-packages/torch/autograd/anomaly_mode.py:70: UserWarning: Anomaly Detection has been enabled. This mode will increase the runtime and should only be enabled for debugging.
#   warnings.warn('Anomaly Detection has been enabled. '
# Epoch 0 -> Val loss -94.353 | Val Acc.: 0.979
# Model saved
# Epoch 2 -> Val loss -94.37 | Val Acc.: 0.985
# Model saved
# Epoch 4 -> Val loss -94.374 | Val Acc.: 0.986
# Model saved
# Epoch 6 -> Val loss -94.375 | Val Acc.: 0.986
# Model saved
# Epoch 8 -> Val loss -94.375 | Val Acc.: 0.987
# Model saved

# %%
results
# Out:
# {'model_path': '../saved-models/model-ddn-123-MNIST-[0.8, 0.2]-123-conv-[28, 28, 1]-10-[64, 64, 64]-5-None-5-10-5-2-64-0.0001-Dir-LL-None-None',
#  'result_path': '../saved-results/results-ddn-123-MNIST-[0.8, 0.2]-123-conv-[28, 28, 1]-10-[64, 64, 64]-5-None-5-10-5-2-64-0.0001-Dir-LL-None-None.csv',
#  'train_losses': [],
#  'val_losses': [-94.352887890625,
#   -94.36979967447917,
#   -94.37354934895833,
#   -94.3749390625,
#   -94.3754314453125],
#  'train_accuracies': [],
#  'val_accuracies': [0.9790833592414856,
#   0.9848333597183228,
#   0.9860000014305115,
#   0.9862499833106995,
#   0.9865833520889282],
#  'fail_trace': <function seml.evaluation.get_results(db_collection_name, fields=None, to_data_frame=False, mongodb_config=None, states=None, filter_dict=None, parallel=False)>,
#  'accuracy': array(0.9886),
#  'confidence_aleatoric_apr': 0.9996631299669728,
#  'confidence_epistemic_apr': 0.9994707336397702,
#  'confidence_aleatoric_auroc': 0.9718412711933586,
#  'confidence_epistemic_auroc': 0.9576638592232147,
#  'brier_score': array(0.62686455, dtype=float32),
#  'anomaly_detection_aleatoric_KMNIST_apr': 0.9718536646119875,
#  'anomaly_detection_epistemic_KMNIST_apr': 0.9160802435444098,
#  'anomaly_detection_aleatoric_KMNIST_auroc': 0.967755125,
#  'anomaly_detection_epistemic_KMNIST_auroc': 0.89797371,
#  'anomaly_detection_aleatoric_FMNIST_apr': 0.968713525652291,
#  'anomaly_detection_epistemic_FMNIST_apr': 0.9555155061306824,
#  'anomaly_detection_aleatoric_FMNIST_auroc': 0.962788135,
#  'anomaly_detection_epistemic_FMNIST_auroc': 0.950788585}

# %% [markdown]
# # Randomized Training

# %%
# Dataset parameters
seed_dataset=123
dataset_name='MNIST'
ood_dataset_names=['KMNIST', 'FMNIST']
split=[.8, .2]

# Architecture parameters
seed_model=123
directory_model='../saved-models'
architecture='conv'
input_dims=[28, 28, 1]
output_dim=10
hidden_dims=[64, 64, 64]
kernel_dim=5
k_lipschitz=None
n_networks=5

# Training parameters
directory_results='../saved-results'
max_epochs=10
patience=5
frequency=2
batch_size=64
lr=1e-4
loss='Dir-LL'
adversarial_training = None
rs_sigma = .1

# %%
results = run(
        # Dataset parameters
        seed_dataset,  # Seed to shuffle dataset. int
        dataset_name,  # Dataset name. string
        ood_dataset_names,  # OOD dataset names.  list of strings
        split,  # Split for train/val/test sets. list of floats

        # Architecture parameters
        seed_model,  # Seed to init model. int
        directory_model,  # Path to save model. string
        architecture,  # Encoder architecture name. string
        input_dims,  # Input dimension. List of ints
        output_dim,  # Output dimension. int
        hidden_dims,  # Hidden dimensions. list of ints
        kernel_dim,  # Input dimension. int
        k_lipschitz,  # Lipschitz constant. float or None (if no lipschitz)
        n_networks,  # Number of networks in ensemble. int

        # Training parameters
        directory_results,  # Path to save resutls. string
        max_epochs,  # Maximum number of epochs for training
        patience,  # Patience for early stopping. int
        frequency,  # Frequency for early stopping test. int
        batch_size,  # Batch size. int
        lr,  # Learning rate. float
        loss,  # Loss name. string

        adversarial_training,  # adversarial training
        rs_sigma,  # rs training
)
# Out:
# 2021-06-08 16:55:02 (INFO): Received the following configuration:
# 2021-06-08 16:55:02 (INFO): DATASET | seed_dataset 123 - dataset_name MNIST - ood_dataset_names ['KMNIST', 'FMNIST'] - split [0.8, 0.2]
# 2021-06-08 16:55:02 (INFO): ARCHITECTURE |  seed_model 123 -  architecture conv -  input_dims [28, 28, 1] -  output_dim 10 -  hidden_dims [64, 64, 64] -  kernel_dim 5 -  k_lipschitz None -  n_networks 5
# 2021-06-08 16:55:02 (INFO): TRAINING |  max_epochs 10 -  patience 5 -  frequency 2 -  batch_size 64 -  lr 0.0001 -  loss Dir-LL
# Sub-model 0
# Epoch 0 -> Val loss 0.232 | Val Acc.: 0.932
# Model saved
# Epoch 2 -> Val loss 0.097 | Val Acc.: 0.97
# Model saved
# Epoch 4 -> Val loss 0.071 | Val Acc.: 0.978
# Model saved
# Epoch 6 -> Val loss 0.057 | Val Acc.: 0.983
# Model saved
# Epoch 8 -> Val loss 0.053 | Val Acc.: 0.983
# Model saved
#
# Sub-model 1
# Epoch 0 -> Val loss 0.242 | Val Acc.: 0.925
# Model saved
# Epoch 2 -> Val loss 0.101 | Val Acc.: 0.97
# Model saved
# Epoch 4 -> Val loss 0.083 | Val Acc.: 0.974
# Model saved
# Epoch 6 -> Val loss 0.063 | Val Acc.: 0.981
# Model saved
# Epoch 8 -> Val loss 0.063 | Val Acc.: 0.98
# Model saved
#
# Sub-model 2
# Epoch 0 -> Val loss 0.232 | Val Acc.: 0.931
# Model saved
# Epoch 2 -> Val loss 0.108 | Val Acc.: 0.965
# Model saved
# Epoch 4 -> Val loss 0.073 | Val Acc.: 0.977
# Model saved
# Epoch 6 -> Val loss 0.061 | Val Acc.: 0.982
# Model saved
# Epoch 8 -> Val loss 0.071 | Val Acc.: 0.977
#
# Sub-model 3
# Epoch 0 -> Val loss 0.221 | Val Acc.: 0.94
# Model saved
# Epoch 2 -> Val loss 0.088 | Val Acc.: 0.973
# Model saved
# Epoch 4 -> Val loss 0.077 | Val Acc.: 0.976
# Model saved
# Epoch 6 -> Val loss 0.063 | Val Acc.: 0.981
# Model saved
# Epoch 8 -> Val loss 0.048 | Val Acc.: 0.984
# Model saved
#
# Sub-model 4
# Epoch 0 -> Val loss 0.215 | Val Acc.: 0.934
# Model saved
# Epoch 2 -> Val loss 0.099 | Val Acc.: 0.969
# Model saved
# Epoch 4 -> Val loss 0.078 | Val Acc.: 0.974
# Model saved
# Epoch 6 -> Val loss 0.054 | Val Acc.: 0.983
# Model saved
# Epoch 8 -> Val loss 0.054 | Val Acc.: 0.983
# Model saved
# cuda
#
# Student Model
# Epoch 0 -> Val loss -93.17 | Val Acc.: 0.974
# Model saved
# Epoch 2 -> Val loss -93.131 | Val Acc.: 0.972
# Epoch 4 -> Val loss -93.119 | Val Acc.: 0.972
# Epoch 6 -> Val loss -93.115 | Val Acc.: 0.974
# Epoch 8 -> Val loss -93.1 | Val Acc.: 0.973

# %%
results
# Out:
# {'model_path': '../saved-models/model-ddn-123-MNIST-[0.8, 0.2]-123-conv-[28, 28, 1]-10-[64, 64, 64]-5-None-5-10-5-2-64-0.0001-Dir-LL-None-0.1',
#  'result_path': '../saved-results/results-ddn-123-MNIST-[0.8, 0.2]-123-conv-[28, 28, 1]-10-[64, 64, 64]-5-None-5-10-5-2-64-0.0001-Dir-LL-None-0.1.csv',
#  'train_losses': [],
#  'val_losses': [-93.17015950520833,
#   -93.131215234375,
#   -93.1191875,
#   -93.11543528645834,
#   -93.0996859375],
#  'train_accuracies': [],
#  'val_accuracies': [0.9735000133514404,
#   0.971833348274231,
#   0.9715833067893982,
#   0.9737499952316284,
#   0.9726666808128357],
#  'fail_trace': <function seml.evaluation.get_results(db_collection_name, fields=None, to_data_frame=False, mongodb_config=None, states=None, filter_dict=None, parallel=False)>,
#  'accuracy': array(0.9771),
#  'confidence_aleatoric_apr': 0.9989951637746937,
#  'confidence_epistemic_apr': 0.9981910886302405,
#  'confidence_aleatoric_auroc': 0.9601896530996501,
#  'confidence_epistemic_auroc': 0.9369929463312476,
#  'brier_score': array(0.64242136, dtype=float32),
#  'anomaly_detection_aleatoric_KMNIST_apr': 0.9636772888644108,
#  'anomaly_detection_epistemic_KMNIST_apr': 0.6722109583068573,
#  'anomaly_detection_aleatoric_KMNIST_auroc': 0.9581272050000001,
#  'anomaly_detection_epistemic_KMNIST_auroc': 0.6524215549999999,
#  'anomaly_detection_aleatoric_FMNIST_apr': 0.9833778044547883,
#  'anomaly_detection_epistemic_FMNIST_apr': 0.8663826630867738,
#  'anomaly_detection_aleatoric_FMNIST_auroc': 0.9779646300000001,
#  'anomaly_detection_epistemic_FMNIST_auroc': 0.8222979699999999}

# %% [markdown]
# # Adversarial Training

# %%
# Dataset parameters
seed_dataset=123
dataset_name='MNIST'
ood_dataset_names=['KMNIST', 'FMNIST']
split=[.8, .2]

# Architecture parameters
seed_model=123
directory_model='../saved-models'
architecture='conv'
input_dims=[28, 28, 1]
output_dim=10
hidden_dims=[64, 64, 64]
kernel_dim=5
k_lipschitz=None
n_networks=5

# Training parameters
directory_results='../saved-results'
max_epochs=10
patience=5
frequency=2
batch_size=64
lr=1e-4
loss='Dir-LL'
adversarial_training = {'shared': {'attack_name': 'PGD_L2',
                                   'attack_loss': 'crossentropy',
                                   'bounds': [0., 1.],
                                   'criterion_params': {'threshold': None,
                                                        'start_data': 'in'},
                                   'attack_params': {'epsilons': [1.0],
                                                     'loss_name': 'crossentropy',
                                                     'punished_measure': None,
                                                     'data_type': 'in'},
                                   'attack_kwargs': {'steps': 5}}}
rs_sigma = None

# %%
results = run(
        # Dataset parameters
        seed_dataset,  # Seed to shuffle dataset. int
        dataset_name,  # Dataset name. string
        ood_dataset_names,  # OOD dataset names.  list of strings
        split,  # Split for train/val/test sets. list of floats

        # Architecture parameters
        seed_model,  # Seed to init model. int
        directory_model,  # Path to save model. string
        architecture,  # Encoder architecture name. string
        input_dims,  # Input dimension. List of ints
        output_dim,  # Output dimension. int
        hidden_dims,  # Hidden dimensions. list of ints
        kernel_dim,  # Input dimension. int
        k_lipschitz,  # Lipschitz constant. float or None (if no lipschitz)
        n_networks,  # Number of networks in ensemble. int

        # Training parameters
        directory_results,  # Path to save resutls. string
        max_epochs,  # Maximum number of epochs for training
        patience,  # Patience for early stopping. int
        frequency,  # Frequency for early stopping test. int
        batch_size,  # Batch size. int
        lr,  # Learning rate. float
        loss,  # Loss name. string

        adversarial_training,  # adversarial training
        rs_sigma,  # rs training
)
# Out:
# 2021-06-08 17:09:53 (INFO): Received the following configuration:
# 2021-06-08 17:09:53 (INFO): DATASET | seed_dataset 123 - dataset_name MNIST - ood_dataset_names ['KMNIST', 'FMNIST'] - split [0.8, 0.2]
# 2021-06-08 17:09:53 (INFO): ARCHITECTURE |  seed_model 123 -  architecture conv -  input_dims [28, 28, 1] -  output_dim 10 -  hidden_dims [64, 64, 64] -  kernel_dim 5 -  k_lipschitz None -  n_networks 5
# 2021-06-08 17:09:53 (INFO): TRAINING |  max_epochs 10 -  patience 5 -  frequency 2 -  batch_size 64 -  lr 0.0001 -  loss Dir-LL
# 2021-06-08 17:09:53 (INFO): shared: {'attack_name': 'PGD_L2', 'attack_loss': 'crossentropy', 'bounds': [0.0, 1.0], 'criterion_params': {'threshold': None, 'start_data': 'in'}, 'attack_params': {'epsilons': [1.0], 'loss_name': 'crossentropy', 'punished_measure': None, 'data_type': 'in'}, 'attack_kwargs': {'steps': 5}}
# Sub-model 0
# Epoch 0 -> Val loss 0.233 | Val Acc.: 0.933
# Model saved
# Epoch 2 -> Val loss 0.101 | Val Acc.: 0.97
# Model saved
# Epoch 4 -> Val loss 0.07 | Val Acc.: 0.98
# Model saved
# Epoch 6 -> Val loss 0.064 | Val Acc.: 0.98
# Model saved
# Epoch 8 -> Val loss 0.051 | Val Acc.: 0.983
# Model saved
#
# Sub-model 1
# Epoch 0 -> Val loss 0.246 | Val Acc.: 0.924
# Model saved
# Epoch 2 -> Val loss 0.11 | Val Acc.: 0.966
# Model saved
# Epoch 4 -> Val loss 0.077 | Val Acc.: 0.977
# Model saved
# Epoch 6 -> Val loss 0.078 | Val Acc.: 0.975
# Epoch 8 -> Val loss 0.059 | Val Acc.: 0.982
# Model saved
#
# Sub-model 2
# Epoch 0 -> Val loss 0.264 | Val Acc.: 0.92
# Model saved
# Epoch 2 -> Val loss 0.097 | Val Acc.: 0.971
# Model saved
# Epoch 4 -> Val loss 0.07 | Val Acc.: 0.979
# Model saved
# Epoch 6 -> Val loss 0.063 | Val Acc.: 0.982
# Model saved
# Epoch 8 -> Val loss 0.049 | Val Acc.: 0.984
# Model saved
#
# Sub-model 3
# Epoch 0 -> Val loss 0.25 | Val Acc.: 0.922
# Model saved
# Epoch 2 -> Val loss 0.102 | Val Acc.: 0.968
# Model saved
# Epoch 4 -> Val loss 0.074 | Val Acc.: 0.977
# Model saved
# Epoch 6 -> Val loss 0.057 | Val Acc.: 0.983
# Model saved
# Epoch 8 -> Val loss 0.064 | Val Acc.: 0.98
#
# Sub-model 4
# Epoch 0 -> Val loss 0.243 | Val Acc.: 0.927
# Model saved
# Epoch 2 -> Val loss 0.111 | Val Acc.: 0.965
# Model saved
# Epoch 4 -> Val loss 0.079 | Val Acc.: 0.976
# Model saved
# Epoch 6 -> Val loss 0.057 | Val Acc.: 0.983
# Model saved
# Epoch 8 -> Val loss 0.046 | Val Acc.: 0.986
# Model saved
# cuda
#
# Student Model
# Epoch 0 -> Val loss -92.937 | Val Acc.: 0.979
# Model saved
# Epoch 2 -> Val loss -92.951 | Val Acc.: 0.985
# Model saved
# Epoch 4 -> Val loss -92.954 | Val Acc.: 0.985
# Model saved
# Epoch 6 -> Val loss -92.955 | Val Acc.: 0.986
# Model saved
# Epoch 8 -> Val loss -92.956 | Val Acc.: 0.987
# Model saved

# %%
results
# Out:
# {'model_path': '../saved-models/model-ddn-123-MNIST-[0.8, 0.2]-123-conv-[28, 28, 1]-10-[64, 64, 64]-5-None-5-10-5-2-64-0.0001-Dir-LL-PGD_L2-crossentropy-[0.0, 1.0]-None-in-[1.0]-crossentropy-None-in-5-None',
#  'result_path': '../saved-results/results-ddn-123-MNIST-[0.8, 0.2]-123-conv-[28, 28, 1]-10-[64, 64, 64]-5-None-5-10-5-2-64-0.0001-Dir-LL-PGD_L2-crossentropy-[0.0, 1.0]-None-in-[1.0]-crossentropy-None-in-5-None.csv',
#  'train_losses': [],
#  'val_losses': [-92.93748268229167,
#   -92.95094583333334,
#   -92.95381028645834,
#   -92.95478997395833,
#   -92.95626080729167],
#  'train_accuracies': [],
#  'val_accuracies': [0.9790833592414856,
#   0.9850000143051147,
#   0.9854999780654907,
#   0.9861666560173035,
#   0.9868333339691162],
#  'fail_trace': <function seml.evaluation.get_results(db_collection_name, fields=None, to_data_frame=False, mongodb_config=None, states=None, filter_dict=None, parallel=False)>,
#  'accuracy': array(0.9906),
#  'confidence_aleatoric_apr': 0.9996568100706811,
#  'confidence_epistemic_apr': 0.9995590442517146,
#  'confidence_aleatoric_auroc': 0.9651511441593532,
#  'confidence_epistemic_auroc': 0.955972309926071,
#  'brier_score': array(0.6261851, dtype=float32),
#  'anomaly_detection_aleatoric_KMNIST_apr': 0.9724327900696773,
#  'anomaly_detection_epistemic_KMNIST_apr': 0.9364942027035241,
#  'anomaly_detection_aleatoric_KMNIST_auroc': 0.96854076,
#  'anomaly_detection_epistemic_KMNIST_auroc': 0.92402406,
#  'anomaly_detection_aleatoric_FMNIST_apr': 0.9725453003875575,
#  'anomaly_detection_epistemic_FMNIST_apr': 0.9883159707647722,
#  'anomaly_detection_aleatoric_FMNIST_auroc': 0.968772895,
#  'anomaly_detection_epistemic_FMNIST_auroc': 0.98597824}
